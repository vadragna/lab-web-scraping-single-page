# %%
import requests

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = 'http://www.popvortex.com/music/charts/top-100-songs.php'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# print(soup.prettify())

# %%
artists = []
titles = []

for title_artist_div in soup.select(".title-artist"):
    title = title_artist_div.find(class_="title")
    artist = title_artist_div.find(class_="artist")
    titles.append(title.get_text())
    artists.append(artist.get_text())

# %%
print(artists)
# Out:
# ['Jimmy Buffett', 'Jimmy Buffett', 'Oliver Anthony Music', 'Jimmy Buffett', 'Jimmy Buffett', 'Jimmy Buffett', 'Jimmy Buffett', 'Doja Cat', 'Nicki Minaj', 'Zach Bryan', 'Jimmy Buffett', 'Luke Combs', 'Paul Russell', 'Miley Cyrus', 'Oliver Anthony Music', 'Jimmy Buffett', 'Taylor Swift', 'Morgan Wallen', 'Jelly Roll', 'Jimmy Buffett', 'Jason Aldean', 'Timbaland, Nelly Furtado & Justin Timberlake', 'Chris Stapleton', 'Jimmy Buffett', 'Jimmy Buffett', 'Dua Lipa', 'Alan Jackson', 'Oliver Anthony Music', 'Jelly Roll', 'Oliver Anthony Music', 'Lainey Wilson', 'Wayland', 'Jimmy Buffett', 'Nickelback', 'Miley Cyrus', 'Morgan Wallen', 'Bailey Zimmerman', 'Teddy Swims', 'Fleetwood Mac', 'Miley Cyrus', 'Crosby, Stills & Nash', 'Rema & Selena Gomez', 'Olivia Rodrigo', 'Jimmy Buffett & Martina McBride', 'Nickelback', 'Jelly Roll', 'Will Dempsey', 'Creedence Clearwater Revival', 'Jimmy Buffett', 'Billie Eilish', 'Radiant Melodies', 'Zac Brown Band', 'Nickelback', 'Nickelback', 'Luke Combs', 'Jimmy Buffett', 'Oliver Anthony Music', 'Zach Bryan', 'Oliver Anthony Music', 'Rod Stewart', 'Nicki Minaj & Ice Spice', 'Jimmy Buffett', 'Selena Gomez', 'Tyler Childers', 'Trump Latinos', 'HARDY', 'Vy Napi', 'Morgan Wallen', 'Kane Brown', 'Jimmy Buffett', 'Taylor Swift', 'Olivia Rodrigo', 'Metallica', 'Chris Stapleton', 'Pretenders', 'Morgan Wallen', 'Noah Kahan & Post Malone', 'Jimmy Buffett', 'Chicago', 'Shazam Conner & H-Town', 'Jimmy Buffett', 'Jimmy Buffett', 'Jimmy Buffett', 'Fleetwood Mac', 'Chicago', 'Fall Out Boy', 'SZA', 'Warren Zeiders', 'Jimmy Buffett', 'Radiant Melodies', 'Norman Greenbaum', 'David Kushner', 'Creedence Clearwater Revival', 'Kylie Minogue', 'Taylor Swift', 'Evanescence', 'Doja Cat', 'Stevie Nicks', 'Creedence Clearwater Revival', 'Fleetwood Mac']

# %%
songs = pd.DataFrame({"title":titles,
                       "artist":artists
                      })

# %%
songs.head()
# Out:
#                                         title                artist
# 0                              Margaritaville         Jimmy Buffett
# 1                                 Come Monday         Jimmy Buffett
# 2                  Rich Men North of Richmond  Oliver Anthony Music
# 3                    Cheeseburger In Paradise         Jimmy Buffett
# 4  Changes In Latitudes, Changes In Attitudes         Jimmy Buffett

# %%
songs.shape
# Out:
# (100, 2)

# %%
Afternoon Lab Lab | Web Scraping Multiple Pages - Part 1

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_songs_recorded_by_Blink-182'
page2 = requests.get(url2)

# %%
soup2 = BeautifulSoup(page2.content, 'html.parser')

# %%
# soup2

# %%
blink_songs = []
selected_elements_blink = soup2.select('table th[scope="row"]')

for song in selected_elements_blink:
    blink_songs.append(song.get_text())
    print(song.get_text())
# Out:
#  "6/8"
#
# "13 Miles"
#
# "21 Days"
#
#  "A New Hope"[b]
#
# "Adam's Song" †
#
# "After Midnight" †
#
# "Aliens Exist"
#
# "All of This"
#
# "All the Small Things" †
#
# "Alone"
#
# "Always" †
#
# "Another Girl, Another Planet" # ‡ (The Only Ones cover)
#
# "Anthem"
#
# "Anthem Part Two"
#
# "Apple Shampoo" †
#
# "Asthenia"
#
#  "Ben Wah Balls"
#
# "Better Days"
#
# "Black Rain"
#
# "Blame It on My Youth" †
#
# "Blow Job"
#
# "Boring"
#
# "Bored to Death" †
#
# "Bored to Death (Acoustic)"
#
# "Bottom of the Ocean"
#
# "Boxing Day"
#
# "Brohemian Rhapsody"
#
# "Built This Pool" #
#
#  "Cacophony"
#
# "California"
#
# "Can't Get You More Pregnant"[c] #
#
# "Carousel"
#
# "The Country Song"[d]
#
# "Cynical"
#
#  "Dammit" †
#
# "Dancing with Myself" ‡ (Generation X cover)
#
# "Darkside" †
#
# "Dead Man's Curve" ‡ (Jan and Dean cover)
#
# "Degenerate"
#
# "Depends"
#
# "Dick Lips" †
#
# "Disaster"
#
# "Does My Breath Smell?"
#
# "Dogs Eating Dogs"
#
# "Don't"
#
# "Don't Leave Me"
#
# "Don't Mean Anything"
#
# "Don't Tell Me It's Over"
#
# "Down" †
#
# "Dumpweed" #
#
# "Dysentery Gary"
#
#  "Easy Target"
#
# "Edging" †
#
# "Emo"
#
# "Enthused"[e]
#
# "Even If She Falls"
#
# "Everytime I Look for You"
#
#  "The Fallen Interlude"
#
# "Falling"[f]
#
# "The Family Next Door"[g]
#
# "Family Reunion" #
#
# "Feeling This" †
#
# "Fentoozler"
#
# "Fighting the Gravity"
#
# "First Date" †
#
# "The First Time"
#
# "Freak Scene" ‡ (Dinosaur Jr. cover)
#
# "Fuck a Dog"
#
#  "Generational Divide" †
#
# "Ghost on the Dance Floor"
#
# "The Girl Next Door" ‡ (Screeching Weasel cover)
#
# "Give Me One Good Reason"
#
# "Go"
#
# "Going Away to College"
#
# "Good Old Days"
#
# "Good Times" ‡ (Good Times theme cover)
#
#  "Happy Days" †
#
#  "Happy Holidays, You Bastard"
#
# "Heart's All Gone"
#
# "Heart's All Gone Interlude"
#
# "Heaven"
#
# "Here's Your Letter"
#
# "Hey I'm Sorry"
#
# "Home Is Such a Lonely Place" †
#
# "Hungover You"
#
#  "I Miss You" †
#
# "I Really Wish I Hated You" †
#
# "I Won't Be Home for Christmas" †[i]
#
# "I'm Lost Without You"
#
# "I'm Sorry"
#
#  "Josie" †
#
# "Just About Done"
#
#  "Kaleidoscope"
#
# "Kings of the Weekend"
#
#  "Last Train Home"
#
# "Left Alone"
#
# "Lemmings"
#
# "Life's So Boring"[j]
#
# "The Longest Line" ‡ (NOFX cover)
#
# "Long Lost Feeling"
#
# "Los Angeles"
#
# "Love Is Dangerous"
#
# "Lunch"
#
#  "M+M's" †
#
# "Man Overboard" †
#
# "Marlboro Man"
#
# "MH 4.18.2011"
#
# "Misery" #
#
# "Mother's Day"
#
# "Mutt"
#
# "My Pet Sally"
#
#  "Natives"
#
# "Nipples of Fury"
#
# "No Future" #
#
# "No Heart to Speak Of"
#
# "Not Another Christmas Song" †
#
# "Not Now" †
#
#  "Obvious"
#
# "Online Songs"
#
# "On Some Emo Shit"
#
# "The Only Thing That Matters"
#
# "Out of My Head"
#
#  "Parking Lot" #
#
# "The Party Song"
#
# "Pathetic"
#
# "Peggy Sue"
#
# "Pin the Grenade"
#
# "Please Take Me Home"
#
# "Point of View"
#
# "Pretty Little Girl"
#
#  "Quarantine" †
#
#  "Rabbit Hole" #
#
# "Ransom"
#
# "Reckless Abandon"
#
# "Red Skies"
#
# "Reebok Commercial"
#
# "Remember to Forget Me"
#
# "The Rock Show" †
#
# "Roller Coaster"
#
# "Romeo and Rebecca"
#
# "Run Away"
#
#  "San Diego"
#
# "She's Out of Her Mind" †
#
# "Shut Up"
#
# "Snake Charmer"
#
# "Sober"
#
# "Sometimes"
#
# "Stay Together for the Kids" †
#
# "Stockholm Syndrome"
#
# "Story of a Lonely Guy"
#
# "Strings"
#
#  "Teenage Satellites"
#
# "This Is Home"
#
# "Time"
#
# "Time to Break Up"
#
# "Toast and Bananas"
#
# "Touchdown Boy"
#
# "Transvestite"[l]
#
# "TV"
#
# "Untitled"
#
# "Up All Night" †
#
#  "Violence"[m]
#
# "Voyeur"[n]
#
# "Voyeur"
#
#  "Waggy"
#
# "Wasting Time" †
#
# "Wendy Clear"
#
# "What Went Wrong"
#
# "What's My Age Again?" †
#
# "When I Was Young"
#
# "When You Fucked Grandpa"
#
# "Wildfire" #
#
# "Wishing Well" #
#
# "Wrecked Him"
#
#  "Zulu"
#
# "Death Bed" (Bonus Remix)[o]
#
# "It's All Fading to Black"[p]
#
# "Let Me Down" †
#
# "P.S. I Hope You're Happy"[q] †
#
# "Scumbag" †
#
# "What's My Age Again?/A Milli"[r] †
#
# "Why Are We So Broken"[s] †
#
# Cheshire Cat
# Dude Ranch
# Enema of the State
# The Mark, Tom, and Travis Show (The Enema Strikes Back!)
# Take Off Your Pants and Jacket
# Blink-182
# Greatest Hits
# Neighborhoods
# California
# Nine
# TBA
# Other songs
# Studio albums
# Live albums
# Compilation albums
# Demos
# EPs
# Video albums
# Tours
# Associated acts
# Related articles

# %%
pattern = r'"(.*?)"'

blink_only_titles = []
for item in blink_songs:
    match = re.search(pattern, item)
    if match:
        blink_only_titles.append(match.group(1))

# %%
blink_only_titles
# Out:
# ['6/8',
#  '13 Miles',
#  '21 Days',
#  'A New Hope',
#  "Adam's Song",
#  'After Midnight',
#  'Aliens Exist',
#  'All of This',
#  'All the Small Things',
#  'Alone',
#  'Always',
#  'Another Girl, Another Planet',
#  'Anthem',
#  'Anthem Part Two',
#  'Apple Shampoo',
#  'Asthenia',
#  'Ben Wah Balls',
#  'Better Days',
#  'Black Rain',
#  'Blame It on My Youth',
#  'Blow Job',
#  'Boring',
#  'Bored to Death',
#  'Bored to Death (Acoustic)',
#  'Bottom of the Ocean',
#  'Boxing Day',
#  'Brohemian Rhapsody',
#  'Built This Pool',
#  'Cacophony',
#  'California',
#  "Can't Get You More Pregnant",
#  'Carousel',
#  'The Country Song',
#  'Cynical',
#  'Dammit',
#  'Dancing with Myself',
#  'Darkside',
#  "Dead Man's Curve",
#  'Degenerate',
#  'Depends',
#  'Dick Lips',
#  'Disaster',
#  'Does My Breath Smell?',
#  'Dogs Eating Dogs',
#  "Don't",
#  "Don't Leave Me",
#  "Don't Mean Anything",
#  "Don't Tell Me It's Over",
#  'Down',
#  'Dumpweed',
#  'Dysentery Gary',
#  'Easy Target',
#  'Edging',
#  'Emo',
#  'Enthused',
#  'Even If She Falls',
#  'Everytime I Look for You',
#  'The Fallen Interlude',
#  'Falling',
#  'The Family Next Door',
#  'Family Reunion',
#  'Feeling This',
#  'Fentoozler',
#  'Fighting the Gravity',
#  'First Date',
#  'The First Time',
#  'Freak Scene',
#  'Fuck a Dog',
#  'Generational Divide',
#  'Ghost on the Dance Floor',
#  'The Girl Next Door',
#  'Give Me One Good Reason',
#  'Go',
#  'Going Away to College',
#  'Good Old Days',
#  'Good Times',
#  'Happy Days',
#  'Happy Holidays, You Bastard',
#  "Heart's All Gone",
#  "Heart's All Gone Interlude",
#  'Heaven',
#  "Here's Your Letter",
#  "Hey I'm Sorry",
#  'Home Is Such a Lonely Place',
#  'Hungover You',
#  'I Miss You',
#  'I Really Wish I Hated You',
#  "I Won't Be Home for Christmas",
#  "I'm Lost Without You",
#  "I'm Sorry",
#  'Josie',
#  'Just About Done',
#  'Kaleidoscope',
#  'Kings of the Weekend',
#  'Last Train Home',
#  'Left Alone',
#  'Lemmings',
#  "Life's So Boring",
#  'The Longest Line',
#  'Long Lost Feeling',
#  'Los Angeles',
#  'Love Is Dangerous',
#  'Lunch',
#  "M+M's",
#  'Man Overboard',
#  'Marlboro Man',
#  'MH 4.18.2011',
#  'Misery',
#  "Mother's Day",
#  'Mutt',
#  'My Pet Sally',
#  'Natives',
#  'Nipples of Fury',
#  'No Future',
#  'No Heart to Speak Of',
#  'Not Another Christmas Song',
#  'Not Now',
#  'Obvious',
#  'Online Songs',
#  'On Some Emo Shit',
#  'The Only Thing That Matters',
#  'Out of My Head',
#  'Parking Lot',
#  'The Party Song',
#  'Pathetic',
#  'Peggy Sue',
#  'Pin the Grenade',
#  'Please Take Me Home',
#  'Point of View',
#  'Pretty Little Girl',
#  'Quarantine',
#  'Rabbit Hole',
#  'Ransom',
#  'Reckless Abandon',
#  'Red Skies',
#  'Reebok Commercial',
#  'Remember to Forget Me',
#  'The Rock Show',
#  'Roller Coaster',
#  'Romeo and Rebecca',
#  'Run Away',
#  'San Diego',
#  "She's Out of Her Mind",
#  'Shut Up',
#  'Snake Charmer',
#  'Sober',
#  'Sometimes',
#  'Stay Together for the Kids',
#  'Stockholm Syndrome',
#  'Story of a Lonely Guy',
#  'Strings',
#  'Teenage Satellites',
#  'This Is Home',
#  'Time',
#  'Time to Break Up',
#  'Toast and Bananas',
#  'Touchdown Boy',
#  'Transvestite',
#  'TV',
#  'Untitled',
#  'Up All Night',
#  'Violence',
#  'Voyeur',
#  'Voyeur',
#  'Waggy',
#  'Wasting Time',
#  'Wendy Clear',
#  'What Went Wrong',
#  "What's My Age Again?",
#  'When I Was Young',
#  'When You Fucked Grandpa',
#  'Wildfire',
#  'Wishing Well',
#  'Wrecked Him',
#  'Zulu',
#  'Death Bed',
#  "It's All Fading to Black",
#  'Let Me Down',
#  "P.S. I Hope You're Happy",
#  'Scumbag',
#  "What's My Age Again?/A Milli",
#  'Why Are We So Broken']
